# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
ls
# Out:
# create_tables.py  etl.ipynb  __pycache__/  sql_queries.py
# data/             etl.py     README.md     test.ipynb

# %%
cd data/
# Out:
# /home/workspace/data

# %%
ls
# Out:
# log_data/  song_data/

# %%
 cd song_data
# Out:
# /home/workspace/data/song_data

# %%
get_files('/home/workspace/data/song_data')
# Out:
# ['/home/workspace/data/song_data/A/A/C/TRAACER128F4290F96.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACPE128F421C1B9.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACHN128F1489601.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACOW128F933E35F.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACCG128F92E8A55.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACTB12903CAAF15.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACSL128F93462F4.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACFV128F935E50B.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACNS128F14A2DF5.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACVS128E078BE39.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACIW12903CC0F6D.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACLV128F427E123.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACQT128F9331780.json',
#  '/home/workspace/data/song_data/A/A/C/TRAACZK128F4243829.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAVG12903CFA543.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAFD128F92F423A.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAEF128F4273421.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAPK128E0786D96.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAVO128F93133D4.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAARJ128F9320760.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAMQ128F1460CD3.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAABD128F429CF47.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAADZ128F9348C2E.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAMO128F1481E7F.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABYW128F4244559.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABYN12903CFD305.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABNV128F425CEE1.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABRB128F9306DD5.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABJL12903CDCF1A.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABVM128F92CA9DC.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABCL128F4286650.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABLR128F423B7E3.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABJV128F1460C49.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABXG128F9318EBD.json',
#  '/home/workspace/data/song_data/A/A/B/TRAABDL12903CAABBA.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCUQ128E0783E2B.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCFL128F149BB0D.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCRU128F423F449.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCAJ12903CDFCC2.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCPZ128F4275C32.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCIX128F4265903.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCEI128F424C983.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCEC128F426456E.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCKL128F423A778.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCXB128F4286BD3.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCYE128F934CE1D.json',
#  '/home/workspace/data/song_data/A/B/C/TRABCTK128F934B224.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAWW128F4250A31.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAFJ128F42AF24E.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAXV128F92F6AE3.json',
#  '/home/workspace/data/song_data/A/B/A/TRABACN128F425B784.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAZH128F930419A.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAVQ12903CBF7E0.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAFP128F931E9A1.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAIO128F42938F9.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAXR128F426515F.json',
#  '/home/workspace/data/song_data/A/B/A/TRABATO128F42627E9.json',
#  '/home/workspace/data/song_data/A/B/A/TRABAXL128F424FC50.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBOP128F931B50D.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBNP128F932546F.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBXU128F92FEF48.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBKX128F4285205.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBJE12903CDB442.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBTA128F933D304.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBLU128F93349CF.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBOR128F4286200.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBVJ128F92F7EAA.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBZN12903CD9297.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBBV128F42967D7.json',
#  '/home/workspace/data/song_data/A/B/B/TRABBAM128F429D223.json']

# %%
song_files = get_files('/home/workspace/data/song_data')

# %%
filepath = song_files[0]
filepath
# Out:
# '/home/workspace/data/song_data/A/A/C/TRAACER128F4290F96.json'

# %%
sr1 = pd.read_json(filepath,typ = 'series')
sr1
# Out:
# num_songs                                         1
# artist_id                        ARMAC4T1187FB3FA4C
# artist_latitude                             40.8262
# artist_longitude                             -74.48
# artist_location                   Morris Plains, NJ
# artist_name               The Dillinger Escape Plan
# song_id                          SOBBUGU12A8C13E95D
# title               Setting Fire to Sleeping Giants
# duration                                    207.778
# year                                           2004
# dtype: object

# %%
df = pd.DataFrame([pd.read_json(filepath,typ = 'series')])
df
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMAC4T1187FB3FA4C         40.82624         -74.47995
#
#      artist_location                artist_name             song_id  \
# 0  Morris Plains, NJ  The Dillinger Escape Plan  SOBBUGU12A8C13E95D
#
#                              title   duration  year
# 0  Setting Fire to Sleeping Giants  207.77751  2004

# %%
df[['song_id','title', 'artist_id', 'year', 'duration']]
# Out:
#               song_id                            title           artist_id  \
# 0  SOBBUGU12A8C13E95D  Setting Fire to Sleeping Giants  ARMAC4T1187FB3FA4C
#
#    year   duration
# 0  2004  207.77751

# %%
df1 = pd.read_json(filepath,typ = 'series')
df1.index
# Out:
# Index(['num_songs', 'artist_id', 'artist_latitude', 'artist_longitude',
#        'artist_location', 'artist_name', 'song_id', 'title', 'duration',
#        'year'],
#       dtype='object')

# %%
pd.DataFrame([sr1], columns = sr1.index)
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMAC4T1187FB3FA4C         40.82624         -74.47995
#
#      artist_location                artist_name             song_id  \
# 0  Morris Plains, NJ  The Dillinger Escape Plan  SOBBUGU12A8C13E95D
#
#                              title   duration  year
# 0  Setting Fire to Sleeping Giants  207.77751  2004

# %%
pd.DataFrame(columns = sr1.index)
# Out:
# Empty DataFrame
# Columns: [num_songs, artist_id, artist_latitude, artist_longitude, artist_location, artist_name, song_id, title, duration, year]
# Index: []

# %%
sr1 = pd.read_json(filepath,typ = 'series')

for i in range(len(song_files)):
    
    song_row = pd.read_json(song_files[i], typ = 'series')
    
    df_add = pd.DataFrame([pd.read_json(song_files[i],typ = 'series')])
    
    song_df = song_df.append(df_add)

song_df = song_df.reset_index(drop = True)

song_df
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMAC4T1187FB3FA4C         40.82624         -74.47995
# 1          1  ARB29H41187B98F0EF         41.88415         -87.63241
# 2          1  ARGIWFO1187B9B55B7              NaN               NaN
# 3          1  ARH4Z031187B9A71F2         40.73197         -74.17418
# 4          1  AR5KOSW1187FB35FF4         49.80388          15.47491
# 5          1  AR0RCMP1187FB3F427         30.08615         -94.10158
# 6          1  ARAJPHH1187FB5566A         40.70380         -73.83168
# 7          1  AR47JEX1187B995D81         37.83721         -94.35868
# 8          1  AROUOZZ1187B9ABE51         40.79195         -73.94512
# 9          1  AREBBGV1187FB523D2              NaN               NaN
# 10         1  ARNTLGG11E2835DDB9              NaN               NaN
# 11         1  ARDNS031187B9924F0         32.67828         -83.22295
# 12         1  AR1Y2PT1187FB5B9CE         27.94017         -82.32547
# 13         1  ARGUVEV1187B98BA17              NaN               NaN
# 14         1  ARNTLGG11E2835DDB9              NaN               NaN
# 15         1  ARXR32B1187FB57099              NaN               NaN
# 16         1  AR7G5I41187FB4CE6C              NaN               NaN
# 17         1  AR10USD1187B99F3F1              NaN               NaN
# 18         1  ARGSJW91187B9B1D6B         35.21962         -80.01955
# 19         1  AR8ZCNI1187B9A069B              NaN               NaN
# 20         1  ARD0S291187B9B7BF5              NaN               NaN
# 21         1  ARD7TVE1187B99BFB1              NaN               NaN
# 22         1  ARMJAGH1187FB546F3         35.14968         -90.04892
# 23         1  ARKRRTF1187B9984DA              NaN               NaN
# 24         1  ARKFYS91187B98E58F              NaN               NaN
# 25         1  ARI3BMM1187FB4255E         38.89910         -77.02900
# 26         1  ARQGYP71187FB44566         34.31109         -94.02978
# 27         1  ARIG6O41187B988BDD         37.16793         -95.84502
# 28         1  AR1ZHYZ1187FB3C717              NaN               NaN
# 29         1  ARHHO3O1187B989413              NaN               NaN
# ..       ...                 ...              ...               ...
# 41         1  ARNF6401187FB57032         40.79086         -73.96644
# 42         1  ARJIE2Y1187B994AB7              NaN               NaN
# 43         1  AR0IAWL1187B9A96D0          8.41770         -80.11278
# 44         1  ARPFHN61187FB575F6         41.88415         -87.63241
# 45         1  ARWB3G61187FB49404              NaN               NaN
# 46         1  AREVWGE1187B9B890A        -13.44200         -41.99520
# 47         1  AR558FS1187FB45658              NaN               NaN
# 48         1  ARQ9BO41187FB5CF1F         40.99471         -77.60454
# 49         1  AR3JMC51187B9AE49D         28.53823         -81.37739
# 50         1  AREDBBQ1187B98AFF5              NaN               NaN
# 51         1  ARD7TVE1187B99BFB1              NaN               NaN
# 52         1  AR7ZKHQ1187B98DD73              NaN               NaN
# 53         1  ARMBR4Y1187B9990EB         37.77916        -122.42005
# 54         1  ARPBNLO1187FB3D52F         40.71455         -74.00712
# 55         1  AR9AWNF1187B9AB0B4              NaN               NaN
# 56         1  ARI2JSK1187FB496EF         51.50632          -0.12714
# 57         1  AROGWRA122988FEE45              NaN               NaN
# 58         1  ARKULSX1187FB45F84         39.49974        -111.54732
# 59         1  ARBEBBY1187B9B43DB              NaN               NaN
# 60         1  AR62SOJ1187FB47BB5              NaN               NaN
# 61         1  ARP6N5A1187B99D1A3              NaN               NaN
# 62         1  AR36F9J1187FB406F1         56.27609           9.51695
# 63         1  ARGCY1Y1187B9A4FA5         36.16778         -86.77836
# 64         1  ARAGB2O1187FB3A161              NaN               NaN
# 65         1  ARNNKDK1187B98BBD5         45.80726          15.96760
# 66         1  ARDR4AC1187FB371A1              NaN               NaN
# 67         1  AREDL271187FB40F44              NaN               NaN
# 68         1  ARGSAFR1269FB35070              NaN               NaN
# 69         1  AR7SMBG1187B9B9066              NaN               NaN
# 70         1  ARBGXIG122988F409D         37.77916        -122.42005
#
#                   artist_location  \
# 0               Morris Plains, NJ
# 1                         Chicago
# 2
# 3                      Newark, NJ
# 4                       Dubai UAE
# 5                    Beaumont, TX
# 6                      Queens, NY
# 7                      Nevada, MO
# 8   New York, NY [Spanish Harlem]
# 9                     Houston, TX
# 10
# 11                        Georgia
# 12                        Brandon
# 13
# 14
# 15
# 16                London, England
# 17    Burlington, Ontario, Canada
# 18                 North Carolina
# 19
# 20                           Ohio
# 21                California - LA
# 22                    Memphis, TN
# 23
# 24
# 25                     Washington
# 26                    Mineola, AR
# 27                  United States
# 28
# 29
# ..                            ...
# 41       New York, NY [Manhattan]
# 42
# 43                         Panama
# 44                    Chicago, IL
# 45                 Hamilton, Ohio
# 46                      Noci (BA)
# 47
# 48                   Pennsylvania
# 49                    Orlando, FL
# 50
# 51                California - LA
# 52
# 53                California - SF
# 54                   New York, NY
# 55        Seattle, Washington USA
# 56                London, England
# 57
# 58                           Utah
# 59                Gainesville, FL
# 60
# 61                  Hamtramck, MI
# 62                        Denmark
# 63                 Nashville, TN.
# 64
# 65                 Zagreb Croatia
# 66
# 67
# 68
# 69
# 70                California - SF
#
#                                           artist_name             song_id  \
# 0                           The Dillinger Escape Plan  SOBBUGU12A8C13E95D
# 1                                       Terry Callier  SOGNCJP12A58A80271
# 2                                      Five Bolt Main  SOPSWQW12A6D4F8781
# 3                                          Faye Adams  SOVYKGO12AB0187199
# 4                                               Elena  SOZCTXZ12AB0182364
# 5                                    Billie Jo Spears  SOGXHEG12AB018653E
# 6                                     The Shangri-Las  SOYTPEP12AB0180E7B
# 7                                        SUE THOMPSON  SOBLGCN12AB0183212
# 8                                         Willie Bobo  SOBZBAZ12A6D4F8742
# 9        Mike Jones (Featuring CJ_ Mello & Lil' Bran)  SOOLYAZ12A6701F4A6
# 10                                                Clp  SOZQDIU12A58A7BCF6
# 11                                         Tim Wilson  SONYPOM12A8C13B2D7
# 12                                        John Wesley  SOLLHMX12AB01846DC
# 13                                     Sierra Maestra  SOGOSOV12AF72A285E
# 14                                                Clp  SOUDSGM12AC9618304
# 15                                                Gob  SOFSOCN12A8C143F5D
# 16                                           Adam Ant  SONHOTT12A8C13493C
# 17                              Tweeterfriendly Music  SOHKNRJ12A6701D1F8
# 18                                       JennyAnyKind  SOQHXMF12AB0182363
# 19                                   Planet P Project  SOIAZJW12AB01853F1
# 20                                            Rated R  SOMJBYD12A6D4F8557
# 21                                             Casual  SOMZWCG12A8C13C480
# 22                                       The Box Tops  SOCIWDW12A8C13D406
# 23                                   Sonora Santanera  SOXVLOJ12AB0189215
# 24                              Jeff And Sheri Easter  SOYMRWW12A6D4FAB14
# 25                                       Alice Stuart  SOBEBDG12A58A76D60
# 26                                       Jimmy Wakely  SOWTBJW12AC468AC6E
# 27                                    Richard Souther  SOUQQEA12A8C134B1B
# 28                                      Faiz Ali Faiz  SOILPQQ12AB017E82A
# 29                                          Bob Azzam  SORAMLE12AB017C8B0
# ..                                                ...                 ...
# 41                                  Sophie B. Hawkins  SONWXQJ12A8C134D94
# 42                                        Line Renaud  SOUPIRU12A6D4FA1E1
# 43                                       Danilo Perez  SONSKXP12A8C13A2C9
# 44                                        Lupe Fiasco  SOWQTQZ12A58A7B63E
# 45                                        Steve Morse  SODAUVL12A8C13D184
# 46                                         Bitter End  SOFCHDR12AB01866EF
# 47                                            40 Grit  SOGDBUF12A8C140FAA
# 48                                         John Davis  SOMVWWT12A58A7AE05
# 49                                    Backstreet Boys  SOPVXLX12A8C1402D5
# 50                                      Eddie Calvert  SOBBXLX12A58A79DDA
# 51                                             Casual  SOQLGFP12A58A7800E
# 52                                               Glad  SOTUKVB12AB0181477
# 53                                       David Martin  SOTTDKS12AB018D69B
# 54                                           Tiny Tim  SOAOIBZ12AB01815BE
# 55                       Kenny G featuring Daryl Hall  SOZHPGD12A8C1394FE
# 56                           Nick Ingman;Gavyn Wright  SODUJBS12A8C132150
# 57                                    Christos Dantis  SOSLAVG12A8C13397F
# 58                                             Trafik  SOQVMXR12A81C21483
# 59                                          Tom Petty  SOFFKZS12AB017F194
# 60                                     Chase & Status  SOGVQGJ12AB017F169
# 61                                        Mitch Ryder  SOXILUQ12A58A7C72A
# 62                                     Bombay Rockers  SOBKWDJ12A8C13B2F3
# 63                                           Gloriana  SOQOTLQ12AB01868D0
# 64                    Pucho & His Latin Soul Brothers  SOLEYHO12AB0188A85
# 65                                               Jinx  SOFNOQK12AB01840FC
# 66  Montserrat Caballé;Placido Domingo;Vicente Sar...  SOBAYLL12A8C138AF9
# 67                                       Soul Mekanik  SOPEGZN12AB0181B3D
# 68                                         Blingtones  SOTCKKY12AB018A141
# 69                                        Los Manolos  SOBCOSW12A8C13D398
# 70                                         Steel Rain  SOOJPRH12A8C141995
#
#                                                 title   duration  year
# 0                     Setting Fire to Sleeping Giants  207.77751  2004
# 1                        Do You Finally Need A Friend  342.56934  1972
# 2                               Made Like This (Live)  225.09669     0
# 3                                Crazy Mixed Up World  156.39465  1961
# 4                                      Setanta matins  269.58322     0
# 5                          It Makes No Difference Now  133.32853  1992
# 6                                     Twist and Shout  164.80608  1964
# 7                      James (Hold The Ladder Steady)  124.86485  1985
# 8                                      Spanish Grease  168.25424  1997
# 9                     Laws Patrolling (Album Version)  173.66159     0
# 10                                  Superconfidential  338.31138     0
# 11  I Think My Wife Is Running Around On Me (Taco ...  186.48771  2005
# 12                                  The Emperor Falls  484.62322     0
# 13                                  ¿Dónde va Chichi?  313.12934  1997
# 14                  Insatiable (Instrumental Version)  266.39628     0
# 15                                     Face the Ashes  209.60608  2007
# 16                                    Something Girls  233.40363  1982
# 17                                       Drop of Rain  189.57016     0
# 18                                    Young Boy Blues  218.77506     0
# 19                                         Pink World  269.81832  1984
# 20                              Keepin It Real (Skit)  114.78159     0
# 21                                   I Didn't Mean To  218.93179     0
# 22                                          Soul Deep  148.03546  1969
# 23                                    Amor De Cabaret  177.47546     0
# 24        The Moon And I (Ordinary Day Album Version)  267.70240     0
# 25                                       Kassie Jones  220.78649     0
# 26                         Broken-Down Merry-Go-Round  151.84934     0
# 27                                          High Tide  228.59710     0
# 28                               Sohna Nee Sohna Data  599.24853     0
# 29                                     Auguri Cha Cha  191.84281     0
# ..                                                ...        ...   ...
# 41                      The Ballad Of Sleeping Beauty  305.16200  1994
# 42                                Der Kleine Dompfaff  152.92036     0
# 43                                        Native Soul  197.19791  2003
# 44           Streets On Fire (Explicit Album Version)  279.97995     0
# 45                                          Prognosis  363.85914  2000
# 46                                        Living Hell  282.43546     0
# 47                                              Intro   75.67628  2003
# 48                            Knocked Out Of The Park  183.17016     0
# 49                                   Larger Than Life  236.25098  1999
# 50                      Erica (2005 Digital Remaster)  138.63138     0
# 51                                            OAKtown  259.44771     0
# 52                                  Blessed Assurance  270.60200  1993
# 53                               It Wont Be Christmas  241.47546     0
# 54  I Hold Your Hand In Mine [Live At Royal Albert...   43.36281  2000
# 55                                    Baby Come To Me  236.93016     0
# 56                               Wessex Loses a Bride  111.62077     0
# 57                                        Den Pai Alo  243.82649     0
# 58                                        Salt In NYC  424.12363     0
# 59                     A Higher Place (Album Version)  236.17261  1994
# 60                                          Ten Tonne  337.68444  2005
# 61                                  Jenny Take a Ride  207.43791  2004
# 62                      Wild Rose (Back 2 Basics Mix)  230.71302     0
# 63                                 Clementina Santafè  153.33832     0
# 64                                 Got My Mojo Workin  338.23302     0
# 65                        Kutt Free (DJ Volume Remix)  407.37914     0
# 66                    Sono andati? Fingevo di dormire  511.16363     0
# 67                   Get Your Head Stuck On Your Neck   45.66159     0
# 68                        Sonnerie lalaleulé hi houuu   29.54404     0
# 69                                 Rumba De Barcelona  218.38322     0
# 70                                  Loaded Like A Gun  173.19138     0
#
# [71 rows x 10 columns]

# %%
df = song_df
df.head()
# Out:
#   num_songs           artist_id  artist_latitude  artist_longitude  \
# 0         1  ARMAC4T1187FB3FA4C         40.82624         -74.47995
# 1         1  ARB29H41187B98F0EF         41.88415         -87.63241
# 2         1  ARGIWFO1187B9B55B7              NaN               NaN
# 3         1  ARH4Z031187B9A71F2         40.73197         -74.17418
# 4         1  AR5KOSW1187FB35FF4         49.80388          15.47491
#
#      artist_location                artist_name             song_id  \
# 0  Morris Plains, NJ  The Dillinger Escape Plan  SOBBUGU12A8C13E95D
# 1            Chicago              Terry Callier  SOGNCJP12A58A80271
# 2                                Five Bolt Main  SOPSWQW12A6D4F8781
# 3         Newark, NJ                 Faye Adams  SOVYKGO12AB0187199
# 4          Dubai UAE                      Elena  SOZCTXZ12AB0182364
#
#                              title   duration  year
# 0  Setting Fire to Sleeping Giants  207.77751  2004
# 1     Do You Finally Need A Friend  342.56934  1972
# 2            Made Like This (Live)  225.09669     0
# 3             Crazy Mixed Up World  156.39465  1961
# 4                   Setanta matins  269.58322     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = song_df[['song_id','title', 'artist_id', 'year', 'duration']]
song_data = list(song_data.values[0])
song_data
# Out:
# ['SOBBUGU12A8C13E95D',
#  'Setting Fire to Sleeping Giants',
#  'ARMAC4T1187FB3FA4C',
#  2004,
#  207.77751]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
song_table_insert
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = song_df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']]
artist_data = list(artist_data.values[0])
artist_data
# Out:
# ['ARMAC4T1187FB3FA4C',
#  'The Dillinger Escape Plan',
#  'Morris Plains, NJ',
#  40.82624,
#  -74.47995]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('/home/workspace/data/log_data')
log_files
# Out:
# ['/home/workspace/data/log_data/2018/11/2018-11-12-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-18-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-04-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-11-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-27-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-29-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-05-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-15-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-23-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-14-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-13-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-06-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-08-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-20-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-02-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-07-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-17-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-28-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-30-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-24-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-26-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-10-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-03-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-19-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-25-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-21-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-16-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-09-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-22-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-01-events.json']

# %%
filepath = log_files[0]
filepath
# Out:
# '/home/workspace/data/log_data/2018/11/2018-11-12-events.json'

# %%
df = pd.read_json(log_files[0], lines = True)
df.head()
# Out:
#                                               artist       auth   firstName  \
# 0                                               None  Logged In     Celeste
# 1                                           Pavement  Logged In      Sylvie
# 2  Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 3                                         Gary Allan  Logged In     Celeste
# 4                                               None  Logged In  Jacqueline
#
#   gender  itemInSession  lastName     length level  \
# 0      F              0  Williams        NaN  free
# 1      F              0      Cruz   99.16036  free
# 2      F              1  Williams  277.15873  free
# 3      F              2  Williams  211.22567  free
# 4      F              0     Lynch        NaN  paid
#
#                                        location method      page  \
# 0                             Klamath Falls, OR    GET      Home
# 1  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  NextSong
# 2                             Klamath Falls, OR    PUT  NextSong
# 3                             Klamath Falls, OR    PUT  NextSong
# 4             Atlanta-Sandy Springs-Roswell, GA    GET      Home
#
#    registration  sessionId                                               song  \
# 0  1.541078e+12        438                                               None
# 1  1.540266e+12        345                               Mercy:The Laundromat
# 2  1.541078e+12        438  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3  1.541078e+12        438                           Nothing On But The Radio
# 4  1.540224e+12        389                                               None
#
#    status             ts                                          userAgent  \
# 0     200  1541990217796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1     200  1541990258796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1541990264796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     200  1541990541796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4     200  1541990714796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     53
# 1     10
# 2     53
# 3     53
# 4     29

# %%
df.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %%
df = df[df['page']=='NextSong']

df.head()

df.ts = df['ts']=pd.to_datetime(df.ts)
df.head()
# Out:
#                                               artist       auth   firstName  \
# 1                                           Pavement  Logged In      Sylvie
# 2  Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 3                                         Gary Allan  Logged In     Celeste
# 5                                 Charttraxx Karaoke  Logged In     Celeste
# 6                                     The Libertines  Logged In  Jacqueline
#
#   gender  itemInSession  lastName     length level  \
# 1      F              0      Cruz   99.16036  free
# 2      F              1  Williams  277.15873  free
# 3      F              2  Williams  211.22567  free
# 5      F              3  Williams  225.17506  free
# 6      F              1     Lynch  179.53914  paid
#
#                                        location method      page  \
# 1  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  NextSong
# 2                             Klamath Falls, OR    PUT  NextSong
# 3                             Klamath Falls, OR    PUT  NextSong
# 5                             Klamath Falls, OR    PUT  NextSong
# 6             Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
#
#    registration  sessionId                                               song  \
# 1  1.540266e+12        345                               Mercy:The Laundromat
# 2  1.541078e+12        438  Horn Concerto No. 4 in E flat K495: II. Romanc...
# 3  1.541078e+12        438                           Nothing On But The Radio
# 5  1.541078e+12        438                                          Fireflies
# 6  1.540224e+12        389                                  The Good Old Days
#
#    status                            ts  \
# 1     200 1970-01-01 00:25:41.990258796
# 2     200 1970-01-01 00:25:41.990264796
# 3     200 1970-01-01 00:25:41.990541796
# 5     200 1970-01-01 00:25:41.990752796
# 6     200 1970-01-01 00:25:41.990842796
#
#                                            userAgent userId
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     10
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 5  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 6  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
time_df = pd.DataFrame()

time_df['hour'] = df.ts.dt.hour
time_df['day'] = df.ts.dt.day
time_df['week'] = df.ts.dt.week
time_df['month'] = df.ts.dt.month
time_df['year'] = df.ts.dt.year
time_df['weekday'] = df.ts.dt.weekday
time_df.head()
# Out:
#    hour  day  week  month  year  weekday
# 1     0    1     1      1  1970        3
# 2     0    1     1      1  1970        3
# 3     0    1     1      1  1970        3
# 5     0    1     1      1  1970        3
# 6     0    1     1      1  1970        3

# %%
#t = 
#t.head()

# %%
#time_data = ()
#column_labels = ()

# %%
time_df
time_df.head()
# Out:
#    hour  day  week  month  year  weekday
# 1     0    1     1      1  1970        3
# 2     0    1     1      1  1970        3
# 3     0    1     1      1  1970        3
# 5     0    1     1      1  1970        3
# 6     0    1     1      1  1970        3

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']]

user_df
# Out:
#     userId   firstName   lastName gender level
# 1       10      Sylvie       Cruz      F  free
# 2       53     Celeste   Williams      F  free
# 3       53     Celeste   Williams      F  free
# 5       53     Celeste   Williams      F  free
# 6       29  Jacqueline      Lynch      F  paid
# 7       29  Jacqueline      Lynch      F  paid
# 8       29  Jacqueline      Lynch      F  paid
# 9       29  Jacqueline      Lynch      F  paid
# 10      29  Jacqueline      Lynch      F  paid
# 11      29  Jacqueline      Lynch      F  paid
# 12      68      Jordan  Rodriguez      F  free
# 18      94        Noah     Chavez      M  free
# 20     100       Adler    Barrera      M  free
# 21     100       Adler    Barrera      M  free
# 22     100       Adler    Barrera      M  free
# 23     100       Adler    Barrera      M  free
# 24      58       Emily     Benson      F  paid
# 25      58       Emily     Benson      F  paid
# 27      34      Evelin      Ayala      F  free
# 28      49       Chloe     Cuevas      F  free
# 29      86       Aiden       Hess      M  free
# 30      86       Aiden       Hess      M  free
# 31      86       Aiden       Hess      M  free
# 32      61      Samuel   Gonzalez      M  free
# 33      86       Aiden       Hess      M  free
# 34      86       Aiden       Hess      M  free
# 35      37      Jordan      Hicks      F  free
# 36      66       Kevin   Arellano      M  free
# 40      26        Ryan      Smith      M  free
# 42      26        Ryan      Smith      M  free
# ..     ...         ...        ...    ...   ...
# 178     58       Emily     Benson      F  paid
# 180     12      Austin    Rosales      M  free
# 181     58       Emily     Benson      F  paid
# 182     58       Emily     Benson      F  paid
# 183     12      Austin    Rosales      M  free
# 184     58       Emily     Benson      F  paid
# 185     12      Austin    Rosales      M  free
# 186     58       Emily     Benson      F  paid
# 187     58       Emily     Benson      F  paid
# 188     12      Austin    Rosales      M  free
# 189     58       Emily     Benson      F  paid
# 190     12      Austin    Rosales      M  free
# 191     58       Emily     Benson      F  paid
# 192     58       Emily     Benson      F  paid
# 193     80       Tegan     Levine      F  paid
# 194     80       Tegan     Levine      F  paid
# 196     80       Tegan     Levine      F  paid
# 197     80       Tegan     Levine      F  paid
# 198     80       Tegan     Levine      F  paid
# 200     68      Jordan  Rodriguez      F  free
# 201     80       Tegan     Levine      F  paid
# 202     80       Tegan     Levine      F  paid
# 203     80       Tegan     Levine      F  paid
# 204     80       Tegan     Levine      F  paid
# 205     80       Tegan     Levine      F  paid
# 206     80       Tegan     Levine      F  paid
# 207     80       Tegan     Levine      F  paid
# 208     80       Tegan     Levine      F  paid
# 209     80       Tegan     Levine      F  paid
# 210     80       Tegan     Levine      F  paid
#
# [166 rows x 5 columns]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
user_df.head()
# Out:
#   userId   firstName  lastName gender level
# 1     10      Sylvie      Cruz      F  free
# 2     53     Celeste  Williams      F  free
# 3     53     Celeste  Williams      F  free
# 5     53     Celeste  Williams      F  free
# 6     29  Jacqueline     Lynch      F  paid

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
